# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %% [markdown]
# Load the data from CSV file into a Pandas dataframe, and print the top few rows.

# %%
# Reading a CSV file named 'iris.csv' into a pandas DataFrame and assigning it to the variable 'data'
data = pd.read_csv('iris.csv')

# Displaying the first few rows of the DataFrame to get an initial overview of the data
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Customize columns

# %% [markdown]
# Drop the redundant id column, and rename Attribute columns to integers. Save column names for use later.

# %%
data = data.drop(columns='Id')

# Correct the column names in the 'cols' list
cols = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
data.columns = cols

# Rename the columns as 0, 1, 2, 3
data.columns = [0, 1, 2, 3, 'Species']

# Display every 50th row
result = data.loc[::50]

print(result)
# Out:
#        0    1    2    3          Species
# 0    5.1  3.5  1.4  0.2      Iris-setosa
# 50   7.0  3.2  4.7  1.4  Iris-versicolor
# 100  6.3  3.3  6.0  2.5   Iris-virginica

# %% [markdown]
# # Statistical Overview

# %% [markdown]
# Show shape of dataframe and statistical overview of attribute columns.

# %%
# Print the shape of the 'data' DataFrame, showing the number of rows and columns
print(data.shape)

# Display descriptive statistics for the 'data' DataFrame, including count, mean, std (standard deviation),
data.describe()
# Out:
# (150, 5)
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# Count the occurrences of each unique value in the 'Species' column
species_counts = data['Species'].value_counts()

# Display the result, showing the count of each species
print(species_counts)
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# # Histograms

# %% [markdown]
# Histograms are useful for showing how the data is distributed. They're ridiculously easy to use, but can only show two axes.

# %%
# Plotting a histogram for the values in the first column of the data
plt.hist(data[0])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Here we give 4 columns of data to the Histogram maker, and it automatically color codes them.

# %%
# Creating a histogram for each column in 'data'
plt.hist([data[0], data[1], data[2], data[3]])
# Out:
# (array([[ 0.,  0.,  0.,  0.,  0., 11., 48., 49., 31., 11.],
#         [ 0.,  0., 11., 97., 38.,  4.,  0.,  0.,  0.,  0.],
#         [ 0., 44.,  6.,  1., 10., 34., 30., 20.,  5.,  0.],
#         [50., 52., 45.,  3.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([0.1 , 0.88, 1.66, 2.44, 3.22, 4.  , 4.78, 5.56, 6.34, 7.12, 7.9 ]),
#  <a list of 4 BarContainer objects>)

# %% [markdown]
# To add a Legend we need to add labels to the Histogram builder as a list of column names, and call the legend function.

# %%
# Creating a histogram for each column in 'data' and labeling each histogram
# with the corresponding column name from 'cols'
plt.hist([data[0], data[1], data[2], data[3]], label=[cols[0], cols[1], cols[2], cols[3]])
# Displaying a legend to identify each histogram with its corresponding label
plt.legend()

# %% [markdown]
# Or we can make 4 separate calls to the Histogram builder and get 4 overlapping plots.

# %%
# Plotting a histogram for the data in column 
plt.hist(data[0])
plt.hist(data[1]) 
plt.hist(data[2])
plt.hist(data[3])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# We can use alpha to control the opacity of plots. alpha of 1 is opague. alpha of 0 is transparent.

# %%
# Plot a histogram for the first column of data
plt.hist(data[0])
# Plot a histogram for the second column of data with higher alpha for transparency
plt.hist(data[1], alpha=1) 
# Plot a histogram for the third column of data with moderate alpha for transparency
plt.hist(data[2], alpha=0.6)
# Plot a histogram for the fourth column of data with lower alpha for transparency
plt.hist(data[3], alpha=0.5)
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
# Create a 2x2 subplot layout with a specified figure size
fig, ax = plt.subplots(2, 2, figsize=(8, 6))
# Plot a histogram for the first column of data in the top-left subplot
ax[0, 0].hist(data[0])
# Plot a histogram for the second column of data in the top-right subplot
ax[0, 1].hist(data[1])
# Plot a histogram for the third column of data in the bottom-left subplot
ax[1, 0].hist(data[2])
# Plot a histogram for the fourth column of data in the bottom-right subplot
ax[1, 1].hist(data[3])
 # Set the title for the subplot
ax[0, 0].set_title(cols[0])
ax[0, 1].set_title(cols[1])
ax[1, 0].set_title(cols[2])
ax[1, 1].set_title(cols[3])
plt.show()

# %% [markdown]
# Adding titles to the plot makes it more readable.

# %% [markdown]
# # Scatter Plots

# %% [markdown]
# These are probably more useful for this dataset because they can show clusters by species. The most basic scatter plot does not distinguish species.

# %%
# Scatter plot of data points from the first column (data[0]) against the second column (data[1])
plt.scatter(
    data[0], 
    data[1],)

# %% [markdown]
# Adding color coding by species allows us to see clustering for 2 attributes for each species. Here setosa is secluded, but virginica and versicolor overlap.

# %%
colors = {'Iris-setosa': 'red', 'Iris-virginica': 'blue', 'Iris-versicolor': 'green'}
plt.scatter(data[2], data[3], c=data['Species'].map(colors))

# Add labels and title if needed
plt.xlabel('PetalLengthCm')
plt.ylabel('PetalWidthCm')
plt.title('Scatter Plot of Petal Length vs. Petal Width')
plt.show()

# %% [markdown]
# Adding labels to the x and y axes is useful, but we can see the data for virginica and versicolor still overlap. If we could find 1 attribute where there's no overlap for these 2 species then we could use those to definitively distinguish them. But unfortunately all 4 attributes have some overlap.

# %%
colors = {'Iris-setosa': 'red', 'Iris-virginica': 'blue', 'Iris-versicolor': 'green'}
plt.scatter(data[0], data[2], c=data['Species'].map(colors))
plt.xlabel(cols[0])
plt.ylabel(cols[2])

plt.show()

# %%
colors = {'Iris-setosa': 'red', 'Iris-virginica': 'blue', 'Iris-versicolor': 'green'}
plt.scatter(data[1], data[3], c=data['Species'].map(colors))
plt.xlabel(cols[1])
plt.ylabel(cols[3])

plt.show()

# %% [markdown]
# # Correlation

# %% [markdown]
# We can see the correlation between attributes. A correlation close to 1 helps us distinguish between species. Low correlation doesn't help us.

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#           0         1         2         3
# 0  1.000000 -0.109369  0.871754  0.817954
# 1 -0.109369  1.000000 -0.420516 -0.356544
# 2  0.871754 -0.420516  1.000000  0.962757
# 3  0.817954 -0.356544  0.962757  1.000000

# %% [markdown]
# # Box and Whisker Plots

# %% [markdown]
# Box plots show the distribution of data over an attribute by showing the 25th, 50th (median) and 75th percentiles. Again, the simplest plots are not very useful, but when we add labels and color coding the plots are revealing.

# %%
plt.boxplot([data[0], data[1], data[2], data[3]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a862e2f010>,
#   <matplotlib.lines.Line2D at 0x1a862bd6e10>,
#   <matplotlib.lines.Line2D at 0x1a862c00190>,
#   <matplotlib.lines.Line2D at 0x1a862c02050>,
#   <matplotlib.lines.Line2D at 0x1a862c06a90>,
#   <matplotlib.lines.Line2D at 0x1a862c06110>,
#   <matplotlib.lines.Line2D at 0x1a862c0a790>,
#   <matplotlib.lines.Line2D at 0x1a862c08e10>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a862bd6690>,
#   <matplotlib.lines.Line2D at 0x1a862bd7ad0>,
#   <matplotlib.lines.Line2D at 0x1a862c007d0>,
#   <matplotlib.lines.Line2D at 0x1a862c03990>,
#   <matplotlib.lines.Line2D at 0x1a862c074d0>,
#   <matplotlib.lines.Line2D at 0x1a862d90890>,
#   <matplotlib.lines.Line2D at 0x1a862c0ae50>,
#   <matplotlib.lines.Line2D at 0x1a862c09290>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a862c1d350>,
#   <matplotlib.lines.Line2D at 0x1a862c03f90>,
#   <matplotlib.lines.Line2D at 0x1a862c04810>,
#   <matplotlib.lines.Line2D at 0x1a862c26490>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a862bd4810>,
#   <matplotlib.lines.Line2D at 0x1a862c02b90>,
#   <matplotlib.lines.Line2D at 0x1a862c24890>,
#   <matplotlib.lines.Line2D at 0x1a862c15b10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a862bd62d0>,
#   <matplotlib.lines.Line2D at 0x1a862c06450>,
#   <matplotlib.lines.Line2D at 0x1a862c24d10>,
#   <matplotlib.lines.Line2D at 0x1a862c14e50>],
#  'means': []}

# %% [markdown]
# This shows a boxplot for one attribute, sorted by species. For this attribute we can see a big overlap between the 3 species, so it's not very useful for distinguishing. An iris with 5.5 or 6.0 for this attribute could be any of the 3 species.

# %%
data.boxplot(column=[0], by=['Species'])
# Out:
# <Axes: title={'center': '0'}, xlabel='[Species]'>

# %% [markdown]
# It's tricky to do subplots, but worth it. We can see setosa has smaller petals than the other 2 species. And versicolor has, on average, smaller sepals and smaller petals than virginica; but there is some overlap.

# %%
fig, ax = plt.subplots(2, 2, figsize=(8, 6))

A = [data[0][data['Species'] == 'Iris-setosa'], data[0][data['Species'] == 'Iris-virginica'], data[0][data['Species'] == 'Iris-versicolor']]
B = [data[1][data['Species'] == 'Iris-setosa'], data[1][data['Species'] == 'Iris-virginica'], data[1][data['Species'] == 'Iris-versicolor']]
C = [data[2][data['Species'] == 'Iris-setosa'], data[2][data['Species'] == 'Iris-virginica'], data[2][data['Species'] == 'Iris-versicolor']]
D = [data[3][data['Species'] == 'Iris-setosa'], data[3][data['Species'] == 'Iris-virginica'], data[3][data['Species'] == 'Iris-versicolor']]

ax[0, 0].boxplot(A, widths=0.7)
ax[0, 0].set_title(cols[0])
ax[0, 1].boxplot(B, widths=0.7)
ax[0, 1].set_title(cols[1])
ax[1, 0].boxplot(C, widths=0.7)
ax[1, 0].set_title(cols[2])
ax[1, 1].boxplot(D, widths=0.7)
ax[1, 1].set_title(cols[3])

plt.show()
